# %%
import os
import copy

import bdpy
import numpy as np
import hdf5storage

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
bdata = bdpy.BData('../data/fmri/visrecon_s1.mat')

# %%
bdata.show_metadata()
# Out:
# | Key          | Description            |
# |--------------|------------------------|
# | VoxelData    | Index for voxel data   |
# | Run          | Index for run number   |
# | Block        | Index for block number |
# | voxel_x      | Voxel x coordinate     |
# | voxel_y      | Voxel y coordinate     |
# | voxel_z      | Voxel z coordinate     |
# | L_V1d        | Index for ROI L_V1d    |
# | L_V1v        | Index for ROI L_V1v    |
# | L_V2d        | Index for ROI L_V2d    |
# | L_V2v        | Index for ROI L_V2v    |
# | L_V3         | Index for ROI L_V3     |
# | L_V3A        | Index for ROI L_V3A    |
# | L_V4v        | Index for ROI L_V4v    |
# | L_VP         | Index for ROI L_VP     |
# | R_V1d        | Index for ROI R_V1d    |
# | R_V1v        | Index for ROI R_V1v    |
# | R_V2d        | Index for ROI R_V2d    |
# | R_V2v        | Index for ROI R_V2v    |
# | R_V3         | Index for ROI R_V3     |
# | R_V3A        | Index for ROI R_V3A    |
# | R_V4v        | Index for ROI R_V4v    |
# | R_VP         | Index for ROI R_VP     |
# | V1           | 1 = ROI V1             |
# | V2           | 1 = ROI V2             |
# | Label        | Index for labels       |
# | Condition    | Condition              |
# | StimulusType | Stimulus type          |
# | Image        | Image (100 x 100 px)   |

# %%
stimulus_type = bdata.select('StimulusType').flatten()
stimulus_type.shape
# Out:
# (1172,)

# %%
# Collect stimulus information

# stimulus_name: List of stimulus IDs for each trial
# stimulus_vmap: Dict mapping stimulus ID to human-readable stimulus name
# stimulus_images: Dict mapping stimulus ID to stimulus image

stimulus_name   = []
stimulus_vmap   = {}
stimulus_images = {}


def is_in_dict_array(a: np.ndarray, d: dict):
    for k, v in d.items():
        if np.array_equal(a, v):
            return True
    return False


stimulus_id = 1

for i in range(bdata.dataset.shape[0]):
    if stimulus_type[i] < 0:
        stimulus_name.append(0)
        continue

    img = bdata.select("Image")[i, :]
    img = np.reshape(img, (10, 10), order="F")

    if is_in_dict_array(img, stimulus_images):

        names = [k for k, v in stimulus_images.items() if np.array_equal(img, v)]
        if len(names) != 1:
            raise RuntimeError(f"Invalid image, hit {len(names)}")
        name = names[0]
        stimulus_name.append(name)
        continue
        
    # Random pattern
    if stimulus_type[i] == 1:
        name = f"random_s1-{i:04}"
    
    # Geometric shapes
    if stimulus_type[i] == 2:
        name = f"geometric-{i:04}"

    # Alphabets
    if stimulus_type[i] == 5:
        name = f"alphabets-{i:04}"

    # Alphabets thin
    if stimulus_type[i] == 3:
        name = f"alphabets_thin-{i:04}"

    # Alphabets long
    if stimulus_type[i] == 4:
        name = f"alphabets_long-{i:04}"

    stimulus_images.update({stimulus_id: img})
    stimulus_vmap.update({stimulus_id: name})
    stimulus_name.append(stimulus_id)
    
    stimulus_id += 1

stimulus_vmap.update({0: 'n/a'})

len(stimulus_name)   # -> 1172
len(stimulus_images) # -> 440 + 20
len(stimulus_vmap)   # -> 440 + 20 + 1
# Out:
# 1172
# 460
# 461

# %%
# Rename test stimulus

# Note: this mapping may differ across subjects.
rename_map = {
    'geometric-0093': 'geometric-square',
    'geometric-0095': 'geometric-small_frame',
    'geometric-0097': 'geometric-plus',
    'geometric-0099': 'geometric-X',
    'geometric-0101': 'geometric-large_frame',
    'alphabets_long-0432': 'alphabets_long-n',
    'alphabets_long-0434': 'alphabets_long-e',
    'alphabets_long-0436': 'alphabets_long-u',
    'alphabets_long-0438': 'alphabets_long-r',
    'alphabets_long-0440': 'alphabets_long-o',
    'alphabets-0545': 'alphabets-n',
    'alphabets-0547': 'alphabets-e',
    'alphabets-0549': 'alphabets-u',
    'alphabets-0551': 'alphabets-r',
    'alphabets-0553': 'alphabets-o',
    'alphabets_thin-0319': 'alphabets_thin-n',
    'alphabets_thin-0321': 'alphabets_thin-e',
    'alphabets_thin-0323': 'alphabets_thin-u',
    'alphabets_thin-0325': 'alphabets_thin-r',
    'alphabets_thin-0327': 'alphabets_thin-o',
}

stimulus_vmap_renamed = {}
for k, v in stimulus_vmap.items():
    if v in rename_map:
        v = rename_map[v]
    stimulus_vmap_renamed.update({k: v})

stimulus_vmap = stimulus_vmap_renamed

# %%
# Save stimulus images

for stim_id, img in stimulus_images.items():
    stim_name = stimulus_vmap[stim_id]
    
    if "random" in stim_name:
        outdir = "random"
    else:
        outdir = "test"

    output_file = f"../data/stimulus/{outdir}/1x1/{stim_name}.mat"
    if os.path.exists(output_file):
        continue
        
    os.makedirs(f"../data/stimulus/{outdir}/1x1", exist_ok=True)

    img = img[np.newaxis, :]
    hdf5storage.write(img, 'feat', output_file, matlab_compatible=True)
    print(f"Saved {output_file}")
# Out:
# /home/kujaku/libraries/python/anaconda3-2020.11/lib/python3.8/site-packages/hdf5storage/__init__.py:1306: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   f = h5py.File(filename)
# Saved ../data/stimulus/random/1x1/random_s1-0001.mat
# Saved ../data/stimulus/random/1x1/random_s1-0003.mat
# Saved ../data/stimulus/random/1x1/random_s1-0005.mat
# Saved ../data/stimulus/random/1x1/random_s1-0007.mat
# Saved ../data/stimulus/random/1x1/random_s1-0009.mat
# Saved ../data/stimulus/random/1x1/random_s1-0011.mat
# Saved ../data/stimulus/random/1x1/random_s1-0013.mat
# Saved ../data/stimulus/random/1x1/random_s1-0015.mat
# Saved ../data/stimulus/random/1x1/random_s1-0017.mat
# Saved ../data/stimulus/random/1x1/random_s1-0019.mat
# Saved ../data/stimulus/random/1x1/random_s1-0021.mat
# Saved ../data/stimulus/random/1x1/random_s1-0023.mat
# Saved ../data/stimulus/random/1x1/random_s1-0025.mat
# Saved ../data/stimulus/random/1x1/random_s1-0027.mat
# Saved ../data/stimulus/random/1x1/random_s1-0029.mat
# Saved ../data/stimulus/random/1x1/random_s1-0031.mat
# Saved ../data/stimulus/random/1x1/random_s1-0033.mat
# Saved ../data/stimulus/random/1x1/random_s1-0035.mat
# Saved ../data/stimulus/random/1x1/random_s1-0037.mat
# Saved ../data/stimulus/random/1x1/random_s1-0039.mat
# Saved ../data/stimulus/random/1x1/random_s1-0041.mat
# Saved ../data/stimulus/random/1x1/random_s1-0043.mat
# Saved ../data/stimulus/random/1x1/random_s1-0047.mat
# Saved ../data/stimulus/random/1x1/random_s1-0049.mat
# Saved ../data/stimulus/random/1x1/random_s1-0051.mat
# Saved ../data/stimulus/random/1x1/random_s1-0053.mat
# Saved ../data/stimulus/random/1x1/random_s1-0055.mat
# Saved ../data/stimulus/random/1x1/random_s1-0057.mat
# Saved ../data/stimulus/random/1x1/random_s1-0059.mat
# Saved ../data/stimulus/random/1x1/random_s1-0061.mat
# Saved ../data/stimulus/random/1x1/random_s1-0063.mat
# Saved ../data/stimulus/random/1x1/random_s1-0065.mat
# Saved ../data/stimulus/random/1x1/random_s1-0067.mat
# Saved ../data/stimulus/random/1x1/random_s1-0069.mat
# Saved ../data/stimulus/random/1x1/random_s1-0071.mat
# Saved ../data/stimulus/random/1x1/random_s1-0073.mat
# Saved ../data/stimulus/random/1x1/random_s1-0075.mat
# Saved ../data/stimulus/random/1x1/random_s1-0077.mat
# Saved ../data/stimulus/random/1x1/random_s1-0079.mat
# Saved ../data/stimulus/random/1x1/random_s1-0081.mat
# Saved ../data/stimulus/random/1x1/random_s1-0083.mat
# Saved ../data/stimulus/random/1x1/random_s1-0085.mat
# Saved ../data/stimulus/random/1x1/random_s1-0087.mat
# Saved ../data/stimulus/random/1x1/random_s1-0089.mat
# Saved ../data/stimulus/test/1x1/geometric-square.mat
# Saved ../data/stimulus/test/1x1/geometric-small_frame.mat
# Saved ../data/stimulus/test/1x1/geometric-plus.mat
# Saved ../data/stimulus/test/1x1/geometric-X.mat
# Saved ../data/stimulus/test/1x1/geometric-large_frame.mat
# Saved ../data/stimulus/random/1x1/random_s1-0114.mat
# Saved ../data/stimulus/random/1x1/random_s1-0116.mat
# Saved ../data/stimulus/random/1x1/random_s1-0118.mat
# Saved ../data/stimulus/random/1x1/random_s1-0120.mat
# Saved ../data/stimulus/random/1x1/random_s1-0122.mat
# Saved ../data/stimulus/random/1x1/random_s1-0124.mat
# Saved ../data/stimulus/random/1x1/random_s1-0126.mat
# Saved ../data/stimulus/random/1x1/random_s1-0128.mat
# Saved ../data/stimulus/random/1x1/random_s1-0130.mat
# Saved ../data/stimulus/random/1x1/random_s1-0132.mat
# Saved ../data/stimulus/random/1x1/random_s1-0134.mat
# Saved ../data/stimulus/random/1x1/random_s1-0136.mat
# Saved ../data/stimulus/random/1x1/random_s1-0138.mat
# Saved ../data/stimulus/random/1x1/random_s1-0140.mat
# Saved ../data/stimulus/random/1x1/random_s1-0142.mat
# Saved ../data/stimulus/random/1x1/random_s1-0144.mat
# Saved ../data/stimulus/random/1x1/random_s1-0146.mat
# Saved ../data/stimulus/random/1x1/random_s1-0148.mat
# Saved ../data/stimulus/random/1x1/random_s1-0150.mat
# Saved ../data/stimulus/random/1x1/random_s1-0152.mat
# Saved ../data/stimulus/random/1x1/random_s1-0154.mat
# Saved ../data/stimulus/random/1x1/random_s1-0156.mat
# Saved ../data/stimulus/random/1x1/random_s1-0160.mat
# Saved ../data/stimulus/random/1x1/random_s1-0162.mat
# Saved ../data/stimulus/random/1x1/random_s1-0164.mat
# Saved ../data/stimulus/random/1x1/random_s1-0166.mat
# Saved ../data/stimulus/random/1x1/random_s1-0168.mat
# Saved ../data/stimulus/random/1x1/random_s1-0170.mat
# Saved ../data/stimulus/random/1x1/random_s1-0172.mat
# Saved ../data/stimulus/random/1x1/random_s1-0174.mat
# Saved ../data/stimulus/random/1x1/random_s1-0176.mat
# Saved ../data/stimulus/random/1x1/random_s1-0178.mat
# Saved ../data/stimulus/random/1x1/random_s1-0180.mat
# Saved ../data/stimulus/random/1x1/random_s1-0182.mat
# Saved ../data/stimulus/random/1x1/random_s1-0184.mat
# Saved ../data/stimulus/random/1x1/random_s1-0186.mat
# Saved ../data/stimulus/random/1x1/random_s1-0188.mat
# Saved ../data/stimulus/random/1x1/random_s1-0190.mat
# Saved ../data/stimulus/random/1x1/random_s1-0192.mat
# Saved ../data/stimulus/random/1x1/random_s1-0194.mat
# Saved ../data/stimulus/random/1x1/random_s1-0196.mat
# Saved ../data/stimulus/random/1x1/random_s1-0198.mat
# Saved ../data/stimulus/random/1x1/random_s1-0200.mat
# Saved ../data/stimulus/random/1x1/random_s1-0202.mat
# Saved ../data/stimulus/random/1x1/random_s1-0227.mat
# Saved ../data/stimulus/random/1x1/random_s1-0229.mat
# Saved ../data/stimulus/random/1x1/random_s1-0231.mat
# Saved ../data/stimulus/random/1x1/random_s1-0233.mat
# Saved ../data/stimulus/random/1x1/random_s1-0235.mat
# Saved ../data/stimulus/random/1x1/random_s1-0237.mat
# Saved ../data/stimulus/random/1x1/random_s1-0239.mat
# Saved ../data/stimulus/random/1x1/random_s1-0241.mat
# Saved ../data/stimulus/random/1x1/random_s1-0243.mat
# Saved ../data/stimulus/random/1x1/random_s1-0245.mat
# Saved ../data/stimulus/random/1x1/random_s1-0247.mat
# Saved ../data/stimulus/random/1x1/random_s1-0249.mat
# Saved ../data/stimulus/random/1x1/random_s1-0251.mat
# Saved ../data/stimulus/random/1x1/random_s1-0253.mat
# Saved ../data/stimulus/random/1x1/random_s1-0255.mat
# Saved ../data/stimulus/random/1x1/random_s1-0257.mat
# Saved ../data/stimulus/random/1x1/random_s1-0259.mat
# Saved ../data/stimulus/random/1x1/random_s1-0261.mat
# Saved ../data/stimulus/random/1x1/random_s1-0263.mat
# Saved ../data/stimulus/random/1x1/random_s1-0265.mat
# Saved ../data/stimulus/random/1x1/random_s1-0267.mat
# Saved ../data/stimulus/random/1x1/random_s1-0269.mat
# Saved ../data/stimulus/random/1x1/random_s1-0273.mat
# Saved ../data/stimulus/random/1x1/random_s1-0275.mat
# Saved ../data/stimulus/random/1x1/random_s1-0277.mat
# Saved ../data/stimulus/random/1x1/random_s1-0279.mat
# Saved ../data/stimulus/random/1x1/random_s1-0281.mat
# Saved ../data/stimulus/random/1x1/random_s1-0283.mat
# Saved ../data/stimulus/random/1x1/random_s1-0285.mat
# Saved ../data/stimulus/random/1x1/random_s1-0287.mat
# Saved ../data/stimulus/random/1x1/random_s1-0289.mat
# Saved ../data/stimulus/random/1x1/random_s1-0291.mat
# Saved ../data/stimulus/random/1x1/random_s1-0293.mat
# Saved ../data/stimulus/random/1x1/random_s1-0295.mat
# Saved ../data/stimulus/random/1x1/random_s1-0297.mat
# Saved ../data/stimulus/random/1x1/random_s1-0299.mat
# Saved ../data/stimulus/random/1x1/random_s1-0301.mat
# Saved ../data/stimulus/random/1x1/random_s1-0303.mat
# Saved ../data/stimulus/random/1x1/random_s1-0305.mat
# Saved ../data/stimulus/random/1x1/random_s1-0307.mat
# Saved ../data/stimulus/random/1x1/random_s1-0309.mat
# Saved ../data/stimulus/random/1x1/random_s1-0311.mat
# Saved ../data/stimulus/random/1x1/random_s1-0313.mat
# Saved ../data/stimulus/random/1x1/random_s1-0315.mat
# Saved ../data/stimulus/test/1x1/alphabets_thin-n.mat
# Saved ../data/stimulus/test/1x1/alphabets_thin-e.mat
# Saved ../data/stimulus/test/1x1/alphabets_thin-u.mat
# Saved ../data/stimulus/test/1x1/alphabets_thin-r.mat
# Saved ../data/stimulus/test/1x1/alphabets_thin-o.mat
# Saved ../data/stimulus/random/1x1/random_s1-0340.mat
# Saved ../data/stimulus/random/1x1/random_s1-0342.mat
# Saved ../data/stimulus/random/1x1/random_s1-0344.mat
# Saved ../data/stimulus/random/1x1/random_s1-0346.mat
# Saved ../data/stimulus/random/1x1/random_s1-0348.mat
# Saved ../data/stimulus/random/1x1/random_s1-0350.mat
# Saved ../data/stimulus/random/1x1/random_s1-0352.mat
# Saved ../data/stimulus/random/1x1/random_s1-0354.mat
# Saved ../data/stimulus/random/1x1/random_s1-0356.mat
# Saved ../data/stimulus/random/1x1/random_s1-0358.mat
# Saved ../data/stimulus/random/1x1/random_s1-0360.mat
# Saved ../data/stimulus/random/1x1/random_s1-0362.mat
# Saved ../data/stimulus/random/1x1/random_s1-0364.mat
# Saved ../data/stimulus/random/1x1/random_s1-0366.mat
# Saved ../data/stimulus/random/1x1/random_s1-0368.mat
# Saved ../data/stimulus/random/1x1/random_s1-0370.mat
# Saved ../data/stimulus/random/1x1/random_s1-0372.mat
# Saved ../data/stimulus/random/1x1/random_s1-0374.mat
# Saved ../data/stimulus/random/1x1/random_s1-0376.mat
# Saved ../data/stimulus/random/1x1/random_s1-0378.mat
# Saved ../data/stimulus/random/1x1/random_s1-0380.mat
# Saved ../data/stimulus/random/1x1/random_s1-0382.mat
# Saved ../data/stimulus/random/1x1/random_s1-0386.mat
# Saved ../data/stimulus/random/1x1/random_s1-0388.mat
# Saved ../data/stimulus/random/1x1/random_s1-0390.mat
# Saved ../data/stimulus/random/1x1/random_s1-0392.mat
# Saved ../data/stimulus/random/1x1/random_s1-0394.mat
# Saved ../data/stimulus/random/1x1/random_s1-0396.mat
# Saved ../data/stimulus/random/1x1/random_s1-0398.mat
# Saved ../data/stimulus/random/1x1/random_s1-0400.mat
# Saved ../data/stimulus/random/1x1/random_s1-0402.mat
# Saved ../data/stimulus/random/1x1/random_s1-0404.mat
# Saved ../data/stimulus/random/1x1/random_s1-0406.mat
# Saved ../data/stimulus/random/1x1/random_s1-0408.mat
# Saved ../data/stimulus/random/1x1/random_s1-0410.mat
# Saved ../data/stimulus/random/1x1/random_s1-0412.mat
# Saved ../data/stimulus/random/1x1/random_s1-0414.mat
# Saved ../data/stimulus/random/1x1/random_s1-0416.mat
# Saved ../data/stimulus/random/1x1/random_s1-0418.mat
# Saved ../data/stimulus/random/1x1/random_s1-0420.mat
# Saved ../data/stimulus/random/1x1/random_s1-0422.mat
# Saved ../data/stimulus/random/1x1/random_s1-0424.mat
# Saved ../data/stimulus/random/1x1/random_s1-0426.mat
# Saved ../data/stimulus/random/1x1/random_s1-0428.mat
# Saved ../data/stimulus/test/1x1/alphabets_long-n.mat
# Saved ../data/stimulus/test/1x1/alphabets_long-e.mat
# Saved ../data/stimulus/test/1x1/alphabets_long-u.mat
# Saved ../data/stimulus/test/1x1/alphabets_long-r.mat
# Saved ../data/stimulus/test/1x1/alphabets_long-o.mat
# Saved ../data/stimulus/random/1x1/random_s1-0453.mat
# Saved ../data/stimulus/random/1x1/random_s1-0455.mat
# Saved ../data/stimulus/random/1x1/random_s1-0457.mat
# Saved ../data/stimulus/random/1x1/random_s1-0459.mat
# Saved ../data/stimulus/random/1x1/random_s1-0461.mat
# Saved ../data/stimulus/random/1x1/random_s1-0463.mat
# Saved ../data/stimulus/random/1x1/random_s1-0465.mat
# Saved ../data/stimulus/random/1x1/random_s1-0467.mat
# Saved ../data/stimulus/random/1x1/random_s1-0469.mat
# Saved ../data/stimulus/random/1x1/random_s1-0471.mat
# Saved ../data/stimulus/random/1x1/random_s1-0473.mat
# Saved ../data/stimulus/random/1x1/random_s1-0475.mat
# Saved ../data/stimulus/random/1x1/random_s1-0477.mat
# Saved ../data/stimulus/random/1x1/random_s1-0479.mat
# Saved ../data/stimulus/random/1x1/random_s1-0481.mat
# Saved ../data/stimulus/random/1x1/random_s1-0483.mat
# Saved ../data/stimulus/random/1x1/random_s1-0485.mat
# Saved ../data/stimulus/random/1x1/random_s1-0487.mat
# Saved ../data/stimulus/random/1x1/random_s1-0489.mat
# Saved ../data/stimulus/random/1x1/random_s1-0491.mat
# Saved ../data/stimulus/random/1x1/random_s1-0493.mat
# Saved ../data/stimulus/random/1x1/random_s1-0495.mat
# Saved ../data/stimulus/random/1x1/random_s1-0499.mat
# Saved ../data/stimulus/random/1x1/random_s1-0501.mat
# Saved ../data/stimulus/random/1x1/random_s1-0503.mat
# Saved ../data/stimulus/random/1x1/random_s1-0505.mat
# Saved ../data/stimulus/random/1x1/random_s1-0507.mat
# Saved ../data/stimulus/random/1x1/random_s1-0509.mat
# Saved ../data/stimulus/random/1x1/random_s1-0511.mat
# Saved ../data/stimulus/random/1x1/random_s1-0513.mat
# Saved ../data/stimulus/random/1x1/random_s1-0515.mat
# Saved ../data/stimulus/random/1x1/random_s1-0517.mat
# Saved ../data/stimulus/random/1x1/random_s1-0519.mat
# Saved ../data/stimulus/random/1x1/random_s1-0521.mat
# Saved ../data/stimulus/random/1x1/random_s1-0523.mat
# Saved ../data/stimulus/random/1x1/random_s1-0525.mat
# Saved ../data/stimulus/random/1x1/random_s1-0527.mat
# Saved ../data/stimulus/random/1x1/random_s1-0529.mat
# Saved ../data/stimulus/random/1x1/random_s1-0531.mat
# Saved ../data/stimulus/random/1x1/random_s1-0533.mat
# Saved ../data/stimulus/random/1x1/random_s1-0535.mat
# Saved ../data/stimulus/random/1x1/random_s1-0537.mat
# Saved ../data/stimulus/random/1x1/random_s1-0539.mat
# Saved ../data/stimulus/random/1x1/random_s1-0541.mat
# Saved ../data/stimulus/test/1x1/alphabets-n.mat
# Saved ../data/stimulus/test/1x1/alphabets-e.mat
# Saved ../data/stimulus/test/1x1/alphabets-u.mat
# Saved ../data/stimulus/test/1x1/alphabets-r.mat
# Saved ../data/stimulus/test/1x1/alphabets-o.mat
# Saved ../data/stimulus/random/1x1/random_s1-0566.mat
# Saved ../data/stimulus/random/1x1/random_s1-0568.mat
# Saved ../data/stimulus/random/1x1/random_s1-0570.mat
# Saved ../data/stimulus/random/1x1/random_s1-0572.mat
# Saved ../data/stimulus/random/1x1/random_s1-0574.mat
# Saved ../data/stimulus/random/1x1/random_s1-0576.mat
# Saved ../data/stimulus/random/1x1/random_s1-0578.mat
# Saved ../data/stimulus/random/1x1/random_s1-0580.mat
# Saved ../data/stimulus/random/1x1/random_s1-0582.mat
# Saved ../data/stimulus/random/1x1/random_s1-0584.mat
# Saved ../data/stimulus/random/1x1/random_s1-0586.mat
# Saved ../data/stimulus/random/1x1/random_s1-0588.mat
# Saved ../data/stimulus/random/1x1/random_s1-0590.mat
# Saved ../data/stimulus/random/1x1/random_s1-0592.mat
# Saved ../data/stimulus/random/1x1/random_s1-0594.mat
# Saved ../data/stimulus/random/1x1/random_s1-0596.mat
# Saved ../data/stimulus/random/1x1/random_s1-0598.mat
# Saved ../data/stimulus/random/1x1/random_s1-0600.mat
# Saved ../data/stimulus/random/1x1/random_s1-0602.mat
# Saved ../data/stimulus/random/1x1/random_s1-0604.mat
# Saved ../data/stimulus/random/1x1/random_s1-0606.mat
# Saved ../data/stimulus/random/1x1/random_s1-0608.mat
# Saved ../data/stimulus/random/1x1/random_s1-0612.mat
# Saved ../data/stimulus/random/1x1/random_s1-0614.mat
# Saved ../data/stimulus/random/1x1/random_s1-0616.mat
# Saved ../data/stimulus/random/1x1/random_s1-0618.mat
# Saved ../data/stimulus/random/1x1/random_s1-0620.mat
# Saved ../data/stimulus/random/1x1/random_s1-0622.mat
# Saved ../data/stimulus/random/1x1/random_s1-0624.mat
# Saved ../data/stimulus/random/1x1/random_s1-0626.mat
# Saved ../data/stimulus/random/1x1/random_s1-0628.mat
# Saved ../data/stimulus/random/1x1/random_s1-0630.mat
# Saved ../data/stimulus/random/1x1/random_s1-0632.mat
# Saved ../data/stimulus/random/1x1/random_s1-0634.mat
# Saved ../data/stimulus/random/1x1/random_s1-0636.mat
# Saved ../data/stimulus/random/1x1/random_s1-0638.mat
# Saved ../data/stimulus/random/1x1/random_s1-0640.mat
# Saved ../data/stimulus/random/1x1/random_s1-0642.mat
# Saved ../data/stimulus/random/1x1/random_s1-0644.mat
# Saved ../data/stimulus/random/1x1/random_s1-0646.mat
# Saved ../data/stimulus/random/1x1/random_s1-0648.mat
# Saved ../data/stimulus/random/1x1/random_s1-0650.mat
# Saved ../data/stimulus/random/1x1/random_s1-0652.mat
# Saved ../data/stimulus/random/1x1/random_s1-0654.mat
# Saved ../data/stimulus/random/1x1/random_s1-0679.mat
# Saved ../data/stimulus/random/1x1/random_s1-0681.mat
# Saved ../data/stimulus/random/1x1/random_s1-0683.mat
# Saved ../data/stimulus/random/1x1/random_s1-0685.mat
# Saved ../data/stimulus/random/1x1/random_s1-0687.mat
# Saved ../data/stimulus/random/1x1/random_s1-0689.mat
# Saved ../data/stimulus/random/1x1/random_s1-0691.mat
# Saved ../data/stimulus/random/1x1/random_s1-0693.mat
# Saved ../data/stimulus/random/1x1/random_s1-0695.mat
# Saved ../data/stimulus/random/1x1/random_s1-0697.mat
# Saved ../data/stimulus/random/1x1/random_s1-0699.mat
# Saved ../data/stimulus/random/1x1/random_s1-0701.mat
# Saved ../data/stimulus/random/1x1/random_s1-0703.mat
# Saved ../data/stimulus/random/1x1/random_s1-0705.mat
# Saved ../data/stimulus/random/1x1/random_s1-0707.mat
# Saved ../data/stimulus/random/1x1/random_s1-0709.mat
# Saved ../data/stimulus/random/1x1/random_s1-0711.mat
# Saved ../data/stimulus/random/1x1/random_s1-0713.mat
# Saved ../data/stimulus/random/1x1/random_s1-0715.mat
# Saved ../data/stimulus/random/1x1/random_s1-0717.mat
# Saved ../data/stimulus/random/1x1/random_s1-0719.mat
# Saved ../data/stimulus/random/1x1/random_s1-0721.mat
# Saved ../data/stimulus/random/1x1/random_s1-0725.mat
# Saved ../data/stimulus/random/1x1/random_s1-0727.mat
# Saved ../data/stimulus/random/1x1/random_s1-0729.mat
# Saved ../data/stimulus/random/1x1/random_s1-0731.mat
# Saved ../data/stimulus/random/1x1/random_s1-0733.mat
# Saved ../data/stimulus/random/1x1/random_s1-0735.mat
# Saved ../data/stimulus/random/1x1/random_s1-0737.mat
# Saved ../data/stimulus/random/1x1/random_s1-0739.mat
# Saved ../data/stimulus/random/1x1/random_s1-0741.mat
# Saved ../data/stimulus/random/1x1/random_s1-0743.mat
# Saved ../data/stimulus/random/1x1/random_s1-0745.mat
# Saved ../data/stimulus/random/1x1/random_s1-0747.mat
# Saved ../data/stimulus/random/1x1/random_s1-0749.mat
# Saved ../data/stimulus/random/1x1/random_s1-0751.mat
# Saved ../data/stimulus/random/1x1/random_s1-0753.mat
# Saved ../data/stimulus/random/1x1/random_s1-0755.mat
# Saved ../data/stimulus/random/1x1/random_s1-0757.mat
# Saved ../data/stimulus/random/1x1/random_s1-0759.mat
# Saved ../data/stimulus/random/1x1/random_s1-0761.mat
# Saved ../data/stimulus/random/1x1/random_s1-0763.mat
# Saved ../data/stimulus/random/1x1/random_s1-0765.mat
# Saved ../data/stimulus/random/1x1/random_s1-0767.mat
# Saved ../data/stimulus/random/1x1/random_s1-0792.mat
# Saved ../data/stimulus/random/1x1/random_s1-0794.mat
# Saved ../data/stimulus/random/1x1/random_s1-0796.mat
# Saved ../data/stimulus/random/1x1/random_s1-0798.mat
# Saved ../data/stimulus/random/1x1/random_s1-0800.mat
# Saved ../data/stimulus/random/1x1/random_s1-0802.mat
# Saved ../data/stimulus/random/1x1/random_s1-0804.mat
# Saved ../data/stimulus/random/1x1/random_s1-0806.mat
# Saved ../data/stimulus/random/1x1/random_s1-0808.mat
# Saved ../data/stimulus/random/1x1/random_s1-0810.mat
# Saved ../data/stimulus/random/1x1/random_s1-0812.mat
# Saved ../data/stimulus/random/1x1/random_s1-0814.mat
# Saved ../data/stimulus/random/1x1/random_s1-0816.mat
# Saved ../data/stimulus/random/1x1/random_s1-0818.mat
# Saved ../data/stimulus/random/1x1/random_s1-0820.mat
# Saved ../data/stimulus/random/1x1/random_s1-0822.mat
# Saved ../data/stimulus/random/1x1/random_s1-0824.mat
# Saved ../data/stimulus/random/1x1/random_s1-0826.mat
# Saved ../data/stimulus/random/1x1/random_s1-0828.mat
# Saved ../data/stimulus/random/1x1/random_s1-0830.mat
# Saved ../data/stimulus/random/1x1/random_s1-0832.mat
# Saved ../data/stimulus/random/1x1/random_s1-0834.mat
# Saved ../data/stimulus/random/1x1/random_s1-0838.mat
# Saved ../data/stimulus/random/1x1/random_s1-0840.mat
# Saved ../data/stimulus/random/1x1/random_s1-0842.mat
# Saved ../data/stimulus/random/1x1/random_s1-0844.mat
# Saved ../data/stimulus/random/1x1/random_s1-0846.mat
# Saved ../data/stimulus/random/1x1/random_s1-0848.mat
# Saved ../data/stimulus/random/1x1/random_s1-0850.mat
# Saved ../data/stimulus/random/1x1/random_s1-0852.mat
# Saved ../data/stimulus/random/1x1/random_s1-0854.mat
# Saved ../data/stimulus/random/1x1/random_s1-0856.mat
# Saved ../data/stimulus/random/1x1/random_s1-0858.mat
# Saved ../data/stimulus/random/1x1/random_s1-0860.mat
# Saved ../data/stimulus/random/1x1/random_s1-0862.mat
# Saved ../data/stimulus/random/1x1/random_s1-0864.mat
# Saved ../data/stimulus/random/1x1/random_s1-0866.mat
# Saved ../data/stimulus/random/1x1/random_s1-0868.mat
# Saved ../data/stimulus/random/1x1/random_s1-0870.mat
# Saved ../data/stimulus/random/1x1/random_s1-0872.mat
# Saved ../data/stimulus/random/1x1/random_s1-0874.mat
# Saved ../data/stimulus/random/1x1/random_s1-0876.mat
# Saved ../data/stimulus/random/1x1/random_s1-0878.mat
# Saved ../data/stimulus/random/1x1/random_s1-0880.mat
# Saved ../data/stimulus/random/1x1/random_s1-0905.mat
# Saved ../data/stimulus/random/1x1/random_s1-0907.mat
# Saved ../data/stimulus/random/1x1/random_s1-0909.mat
# Saved ../data/stimulus/random/1x1/random_s1-0911.mat
# Saved ../data/stimulus/random/1x1/random_s1-0913.mat
# Saved ../data/stimulus/random/1x1/random_s1-0915.mat
# Saved ../data/stimulus/random/1x1/random_s1-0917.mat
# Saved ../data/stimulus/random/1x1/random_s1-0919.mat
# Saved ../data/stimulus/random/1x1/random_s1-0921.mat
# Saved ../data/stimulus/random/1x1/random_s1-0923.mat
# Saved ../data/stimulus/random/1x1/random_s1-0925.mat
# Saved ../data/stimulus/random/1x1/random_s1-0927.mat
# Saved ../data/stimulus/random/1x1/random_s1-0929.mat
# Saved ../data/stimulus/random/1x1/random_s1-0931.mat
# Saved ../data/stimulus/random/1x1/random_s1-0933.mat
# Saved ../data/stimulus/random/1x1/random_s1-0935.mat
# Saved ../data/stimulus/random/1x1/random_s1-0937.mat
# Saved ../data/stimulus/random/1x1/random_s1-0939.mat
# Saved ../data/stimulus/random/1x1/random_s1-0941.mat
# Saved ../data/stimulus/random/1x1/random_s1-0943.mat
# Saved ../data/stimulus/random/1x1/random_s1-0945.mat
# Saved ../data/stimulus/random/1x1/random_s1-0947.mat
# Saved ../data/stimulus/random/1x1/random_s1-0951.mat
# Saved ../data/stimulus/random/1x1/random_s1-0953.mat
# Saved ../data/stimulus/random/1x1/random_s1-0955.mat
# Saved ../data/stimulus/random/1x1/random_s1-0957.mat
# Saved ../data/stimulus/random/1x1/random_s1-0959.mat
# Saved ../data/stimulus/random/1x1/random_s1-0961.mat
# Saved ../data/stimulus/random/1x1/random_s1-0963.mat
# Saved ../data/stimulus/random/1x1/random_s1-0965.mat
# Saved ../data/stimulus/random/1x1/random_s1-0967.mat
# Saved ../data/stimulus/random/1x1/random_s1-0969.mat
# Saved ../data/stimulus/random/1x1/random_s1-0971.mat
# Saved ../data/stimulus/random/1x1/random_s1-0973.mat
# Saved ../data/stimulus/random/1x1/random_s1-0975.mat
# Saved ../data/stimulus/random/1x1/random_s1-0977.mat
# Saved ../data/stimulus/random/1x1/random_s1-0979.mat
# Saved ../data/stimulus/random/1x1/random_s1-0981.mat
# Saved ../data/stimulus/random/1x1/random_s1-0983.mat
# Saved ../data/stimulus/random/1x1/random_s1-0985.mat
# Saved ../data/stimulus/random/1x1/random_s1-0987.mat
# Saved ../data/stimulus/random/1x1/random_s1-0989.mat
# Saved ../data/stimulus/random/1x1/random_s1-0991.mat
# Saved ../data/stimulus/random/1x1/random_s1-0993.mat
# Saved ../data/stimulus/random/1x1/random_s1-1018.mat
# Saved ../data/stimulus/random/1x1/random_s1-1020.mat
# Saved ../data/stimulus/random/1x1/random_s1-1022.mat
# Saved ../data/stimulus/random/1x1/random_s1-1024.mat
# Saved ../data/stimulus/random/1x1/random_s1-1026.mat
# Saved ../data/stimulus/random/1x1/random_s1-1028.mat
# Saved ../data/stimulus/random/1x1/random_s1-1030.mat
# Saved ../data/stimulus/random/1x1/random_s1-1032.mat
# Saved ../data/stimulus/random/1x1/random_s1-1034.mat
# Saved ../data/stimulus/random/1x1/random_s1-1036.mat
# Saved ../data/stimulus/random/1x1/random_s1-1038.mat
# Saved ../data/stimulus/random/1x1/random_s1-1040.mat
# Saved ../data/stimulus/random/1x1/random_s1-1042.mat
# Saved ../data/stimulus/random/1x1/random_s1-1044.mat
# Saved ../data/stimulus/random/1x1/random_s1-1046.mat
# Saved ../data/stimulus/random/1x1/random_s1-1048.mat
# Saved ../data/stimulus/random/1x1/random_s1-1050.mat
# Saved ../data/stimulus/random/1x1/random_s1-1052.mat
# Saved ../data/stimulus/random/1x1/random_s1-1054.mat
# Saved ../data/stimulus/random/1x1/random_s1-1056.mat
# Saved ../data/stimulus/random/1x1/random_s1-1058.mat
# Saved ../data/stimulus/random/1x1/random_s1-1060.mat
# Saved ../data/stimulus/random/1x1/random_s1-1064.mat
# Saved ../data/stimulus/random/1x1/random_s1-1066.mat
# Saved ../data/stimulus/random/1x1/random_s1-1068.mat
# Saved ../data/stimulus/random/1x1/random_s1-1070.mat
# Saved ../data/stimulus/random/1x1/random_s1-1072.mat
# Saved ../data/stimulus/random/1x1/random_s1-1074.mat
# Saved ../data/stimulus/random/1x1/random_s1-1076.mat
# Saved ../data/stimulus/random/1x1/random_s1-1078.mat
# Saved ../data/stimulus/random/1x1/random_s1-1080.mat
# Saved ../data/stimulus/random/1x1/random_s1-1082.mat
# Saved ../data/stimulus/random/1x1/random_s1-1084.mat
# Saved ../data/stimulus/random/1x1/random_s1-1086.mat
# Saved ../data/stimulus/random/1x1/random_s1-1088.mat
# Saved ../data/stimulus/random/1x1/random_s1-1090.mat
# Saved ../data/stimulus/random/1x1/random_s1-1092.mat
# Saved ../data/stimulus/random/1x1/random_s1-1094.mat
# Saved ../data/stimulus/random/1x1/random_s1-1096.mat
# Saved ../data/stimulus/random/1x1/random_s1-1098.mat
# Saved ../data/stimulus/random/1x1/random_s1-1100.mat
# Saved ../data/stimulus/random/1x1/random_s1-1102.mat
# Saved ../data/stimulus/random/1x1/random_s1-1104.mat
# Saved ../data/stimulus/random/1x1/random_s1-1106.mat

# %%
# Add stimulus labels in Bdata

bdata.add(np.array(stimulus_name), 'stimulus_name')
bdata.add_vmap('stimulus_name', stimulus_vmap)

# %%
# Make training (random) fMRI data

bdata_random = copy.deepcopy(bdata)

bdata_random.dataset = bdata.dataset[stimulus_type == 1, :]
bdata_random.dataset.shape

bdata_random.save('../data/fmri/visrecon_s1_random.h5')
# Out:
# (440, 3674)

# %%
# Make teset fMRI data

bdata_test = copy.deepcopy(bdata)

index = np.logical_or(np.logical_or(np.logical_or(stimulus_type == 2, stimulus_type == 3), stimulus_type == 4), stimulus_type == 5)

bdata_test.dataset = bdata.dataset[index, :]
bdata_test.dataset.shape

bdata_test.save('../data/fmri/visrecon_s1_test.h5')
# Out:
# (120, 3674)
